# %%
import cv2
import matplotlib.pyplot as plt

# %%
imagem = cv2.imread("a.jpg")
plt.imshow(imagem)

# %%
imagem = cv2.cvtColor(imagem, cv2.COLOR_RGB2BGR)
plt.imshow(imagem)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-fa691c4e5187> in <module>
# ----> 1 imagem = cv2.cvtColor(imagem, cv2.color_RGB2BGR)
#       2 plt.imshow(imagem)
#
# AttributeError: module 'cv2' has no attribute 'color_RGB2BGR'
